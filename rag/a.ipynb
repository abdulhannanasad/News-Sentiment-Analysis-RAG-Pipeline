# %%
# !ping -c 3 huggingface.co
# Out:
# PING huggingface.co (143.204.106.112): 56 data bytes
# 64 bytes from 143.204.106.112: icmp_seq=0 ttl=238 time=80.067 ms
# 64 bytes from 143.204.106.112: icmp_seq=1 ttl=238 time=532.114 ms
# 64 bytes from 143.204.106.112: icmp_seq=2 ttl=238 time=91.338 ms
#
# --- huggingface.co ping statistics ---
# 3 packets transmitted, 3 packets received, 0.0% packet loss
# round-trip min/avg/max/stddev = 80.067/234.506/532.114/210.491 ms
